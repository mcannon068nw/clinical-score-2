# %%
import pandas as pd
import requests
from bioservices import KEGG
import mygene
import pdb
from chembl_webresource_client.new_client import new_client
from mygene import MyGeneInfo
from tqdm import tqdm
from functools import lru_cache
import pandas as pd
# Out:
# /Users/mjc014/.pyenv/versions/3.12.2/lib/python3.12/site-packages/chembl_webresource_client/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version

# %% [markdown]
# ## Biological Plausibility
# In order to provide an additional metric to help review or provide confidence in AI Assisted Literature curation, I am exploring the notion of a **biological plausibility** score. The idea is for any AI extracted drug, gene interaction, assess whether there is any prior knowledge of the drug and gene interaction OR of the drug interacting with any gene pathway containing that gene.

# %% [markdown]
# ### Load dgiLIT data

# %%
df = pd.read_excel('data/final_results_test3.xlsx').drop(labels='Unnamed: 0', axis=1)
print(len(df))
df.head()
# Out:
# 137
#        pmid    drug_name gene_name interaction_occurs_with_gene  \
# 0  37726279   venetoclax     ABCC1                          YES
# 1  37726279  glutathione     ABCC1                          YES
# 2  37004989   Kynurenine       AhR                          YES
# 3  33932119       ONC201       AKT                          YES
# 4  26884600       ONC201       AKT                          YES
#
#   interaction_type                                           evidence  \
# 0       INHIBITING  Genetic and pharmacologic ABCC1 inactivation p...
# 1       ACTIVATING  Consistent with ABCC1-specific export of gluta...
# 2       ACTIVATING  An endogenous AhR ligand, kynurenine (Kyn), wa...
# 3       INHIBITING  The compensatory, pro-survival PI3K/AKT/mTOR p...
# 4       INHIBITING  ONC201 (also called TIC10) is a small molecule...
#
#               gene_concept gene_label  gene_match_type  \
# 0   normalize.gene.hgnc:51      ABCC1              100
# 1   normalize.gene.hgnc:51      ABCC1              100
# 2  normalize.gene.hgnc:348        AHR              100
# 3  normalize.gene.hgnc:391       AKT1               60
# 4  normalize.gene.hgnc:391       AKT1               60
#
#                            drug_concept   drug_label  drug_match_type
# 0       normalize.therapy.rxcui:1747556   venetoclax               80
# 1          normalize.therapy.rxcui:4890  glutathione               80
# 2    normalize.therapy.drugbank:DB02070   Kynurenine               80
# 3  normalize.therapy.iuphar.ligand:9978       ONC201               80
# 4  normalize.therapy.iuphar.ligand:9978       ONC201               80

# %%
df[df['drug_name']=='imatinib']
# Out:
#         pmid drug_name gene_name interaction_occurs_with_gene  \
# 20  16983347  imatinib       Bax                          YES
#
#    interaction_type                                           evidence  \
# 20       ACTIVATING  Imatinib did not modulate the expression or ac...
#
#                gene_concept gene_label  gene_match_type  \
# 20  normalize.gene.hgnc:959        BAX              100
#
#                       drug_concept drug_label  drug_match_type
# 20  normalize.therapy.rxcui:282388   imatinib               80

# %% [markdown]
# #### Identify Gene Pathways
# Use KEGG and Entrez to identify the relevant biological pathways our target gene is involved in and also all the other neighbor genes present in that pathway in some form.

# %%
def get_gene_pathways(gene_symbol):
    """Return KEGG pathways (ID + common name) that a gene is part of."""
    mg = mygene.MyGeneInfo()
    query = mg.query(gene_symbol, fields="entrezgene", species="human")
    if not query['hits']:
        return []
    hit = query['hits'][0]
    entrez_id = hit.get('entrezgene')
    try:
        pathways = kegg.get_pathway_by_gene(entrez_id, "hsa")
        return [(pid, pname) for pid, pname in pathways.items()]
    except Exception:
        return []

def get_genes_in_pathway(pathway_id):
    """Fetch Entrez gene IDs for a KEGG pathway, handling cases with no GENE section."""
    pathway = kegg.get(pathway_id)
    parsed = kegg.parse(pathway)
    genes = []

    # Some KEGG pathways (like disease or resistance maps) have no GENE section.
    if 'GENE' in parsed:
        entries = parsed['GENE']
        if isinstance(entries, dict):
            # Modern KEGG format: {entrez_id: "symbol; description"}
            genes = list(entries.keys())
        elif isinstance(entries, list):
            # Legacy format: [entrez_id, "symbol; description", entrez_id, ...]
            genes = [entries[i] for i in range(0, len(entries), 2)]
    else:
        pass
    return genes

def build_entrez_to_symbol_mapper(entrez_ids):
    """
    Batch-resolve a set of Entrez IDs to symbols via MyGene,
    and return a function you can use in .apply().
    """
    # Unique, stringified, drop NAs
    unique_ids = sorted({str(i) for i in entrez_ids if pd.notna(i)})
    if not unique_ids:
        return lambda x: None

    res = mg.querymany(unique_ids, scopes="entrezgene", fields="symbol", species="human")

    # query -> symbol dict
    mapping = {r["query"]: r.get("symbol") for r in res if "query" in r}

    # The mapper handles either a scalar or a list/tuple
    def mapper(x):
        if x is None or (isinstance(x, float) and pd.isna(x)):
            return None
        if isinstance(x, (list, tuple)):
            return [mapping.get(str(i)) for i in x]
        return mapping.get(str(x))
    return mapper

# %% [markdown]
# #### Identify Drug Targets
# Utilize Chembl to identify known protein interactions for any target drug.

# %%
# TODO: OLD VERSION

def get_drug_target_symbols(drug_name):
    """
    Given a drug name (e.g., 'sunitinib' or 'ONC201'),
    return a DataFrame of all human SINGLE PROTEIN targets with gene symbols.
    """
    molecule = new_client.molecule
    target = new_client.target

    # 1. Find the ChEMBL ID of the drug
    mol_res = molecule.search(drug_name)
    if not mol_res:
        return pd.DataFrame()

    chembl_id = mol_res[0]["molecule_chembl_id"]

    # 2. Get all activities associated with this molecule
    activity = new_client.activity
    acts = activity.filter(molecule_chembl_id=chembl_id)

    target_ids = {a["target_chembl_id"] for a in acts if "target_chembl_id" in a}

    # 3. Pull target metadata and keep only relevant types
    records = []
    for tid in target_ids:
        rec = target.get(tid)
        if rec.get("organism") != "Homo sapiens":
            continue
        if rec.get("target_type") != "SINGLE PROTEIN":
            continue

        comps = rec.get("target_components", [])
        for comp in comps:
            acc = comp.get("accession")
            name = comp.get("component_name")
            gene_sym = comp.get("target_component_synonyms", [])
            gene_sym = [s["component_synonym"] for s in gene_sym if s["syn_type"] == "GENE_SYMBOL"]
            gene_sym = gene_sym[0] if gene_sym else None

            records.append({
                "target_chembl_id": tid,
                "uniprot_accession": acc,
                "protein_name": name,
                "gene_symbol": gene_sym,
                "pref_name": rec.get("pref_name")
            })

    df = pd.DataFrame(records)
    return df.drop_duplicates(subset=["gene_symbol"]).reset_index(drop=True)


def compute_drug_pathway_overlap(drug_targets_df, pathways_df):
    """
    For each pathway, check if any neighbor_symbol is in the set of known drug targets.
    Adds a boolean flag and the overlapping symbols.
    """
    target_genes = set(drug_targets_df["gene_symbol"].dropna().unique())
    
    def overlap_fn(row):
        n = row["neighbor_symbol"]
        if not n or pd.isna(n):
            return None
        if isinstance(n, list):
            overlap = list(set(n) & target_genes)
        else:
            overlap = [n] if n in target_genes else []
        return overlap if overlap else None
    

# TODO: New cache

from functools import lru_cache
import pandas as pd
import time

@lru_cache(maxsize=None)
def get_drug_target_symbols_cached(drug_name):
    """
    Cached + normalized wrapper around ChEMBL target retrieval.
    """
    if not isinstance(drug_name, str) or not drug_name.strip():
        return pd.DataFrame()

    normalized_name = drug_name.strip().lower()
    print(f"Fetching ChEMBL targets for '{normalized_name}'...")
    
    molecule = new_client.molecule
    target = new_client.target
    activity = new_client.activity

    # Try primary search
    mol_res = molecule.search(normalized_name)
    if not mol_res:
        print(f"⚠️ No ChEMBL hits for '{drug_name}'.")
        return pd.DataFrame()

    chembl_id = mol_res[0].get("molecule_chembl_id")
    if not chembl_id:
        print(f"⚠️ No ChEMBL ID for '{drug_name}'.")
        return pd.DataFrame()

    # Fetch activities
    acts = list(activity.filter(molecule_chembl_id=chembl_id))
    if not acts:
        print(f"⚠️ No activity data for {drug_name}.")
        return pd.DataFrame()

    # Collect unique target IDs
    target_ids = {a.get("target_chembl_id") for a in acts if "target_chembl_id" in a and a["target_chembl_id"]}
    if not target_ids:
        print(f"⚠️ No targets found for {drug_name}.")
        return pd.DataFrame()

    # Fetch metadata for each target
    records = []
    for tid in target_ids:
        try:
            rec = target.get(tid)
            if rec.get("organism") != "Homo sapiens":
                continue
            if rec.get("target_type") != "SINGLE PROTEIN":
                continue

            for comp in rec.get("target_components", []):
                acc = comp.get("accession")
                name = comp.get("component_name")
                gene_sym = None
                for s in comp.get("target_component_synonyms", []):
                    if s.get("syn_type") == "GENE_SYMBOL":
                        gene_sym = s.get("component_synonym")
                        break

                records.append({
                    "target_chembl_id": tid,
                    "uniprot_accession": acc,
                    "protein_name": name,
                    "gene_symbol": gene_sym,
                    "pref_name": rec.get("pref_name")
                })
        except Exception as e:
            print(f"Error retrieving target {tid} for {drug_name}: {e}")
            time.sleep(1)
            continue

    df = pd.DataFrame(records)
    if df.empty:
        print(f"⚠️ No protein targets for {drug_name}.")
    return df.drop_duplicates(subset=["gene_symbol"]).reset_index(drop=True)

# %% [markdown]
# #### Map Overlap
# Identify genes in pathways that are known to be targeted by drug in predicted interaction.

# %%
def compute_drug_pathway_overlap(drug_targets_df, pathways_df):
    """
    For each pathway, check if any neighbor_symbol is in the set of known drug targets.
    Adds a boolean flag and the overlapping symbols.
    """
    # --- Guard clause for invalid or missing input ---
    if (
        drug_targets_df is None
        or not isinstance(drug_targets_df, pd.DataFrame)
        or "gene_symbol" not in drug_targets_df.columns
        or drug_targets_df.empty
    ):
        # Return a copy with same expected output columns but all False/None
        result = pathways_df.copy()
        result["drug_target_overlap"] = None
        result["overlap_flag"] = False
        return result
    # ------------------------------------------------

    target_genes = set(drug_targets_df["gene_symbol"].dropna().unique())

    def overlap_fn(row):
        n = row["neighbor_symbol"]
        if not n or pd.isna(n):
            return None
        if isinstance(n, list):
            overlap = list(set(n) & target_genes)
        else:
            overlap = [n] if n in target_genes else []
        return overlap if overlap else None

    pathways_df = pathways_df.copy()
    pathways_df["drug_target_overlap"] = pathways_df.apply(overlap_fn, axis=1)
    pathways_df["overlap_flag"] = pathways_df["drug_target_overlap"].apply(lambda x: bool(x))
    return pathways_df

# %% [markdown]
# ### Analysis
# Put functions together to generate pathway targeting statistics

# %%
kegg = KEGG()
mg = MyGeneInfo()

df['#_additional_pathways_interactions'] = None
df['additional_pathway_interactions'] = None
df['#_additional_genes_in_pathways'] = None
df['additional_genes_in_pathways'] = None

# Identify all Signaling Pathways for Genes
pathways_df = pd.DataFrame()
for idx, row in tqdm(df.iterrows()):
    drug = row['drug_label']
    gene = row['gene_label']

    gene_pathways = get_gene_pathways(gene)

    for pathway in gene_pathways:
        row = {}
        neighbor_genes = get_genes_in_pathway(pathway[0])
        row['gene'] = gene
        row['pathway_id'] = pathway[0]
        row['pathway_label'] = pathway[1]
        row['neighbor_genes'] = neighbor_genes
        pathways_df = pd.concat([pathways_df, pd.DataFrame(row)]).reset_index(drop=True)

mapper = build_entrez_to_symbol_mapper(pathways_df['neighbor_genes'])
pathways_df['neighbor_symbol'] = pathways_df['neighbor_genes'].apply(mapper)

# Identify Drug Targets for Drugs
df['drug_targets'] = None
for idx, row in df.iterrows():
    drug = row['drug_label']
    try:
        targets_df = get_drug_target_symbols_cached(drug)
        df.at[idx, 'drug_targets'] = targets_df if not targets_df.empty else None
    except Exception as e:
        print(f"❌ Failed for {drug}: {e}")

# Map Drug Targets to Pathways, Quantify
for idx, row in df.iterrows():
    drug_targets = row['drug_targets']
    pathways_with_overlap = compute_drug_pathway_overlap(drug_targets,pathways_df)
    answers = pathways_with_overlap[(pathways_with_overlap['overlap_flag']) & (~pathways_with_overlap['neighbor_symbol'].str.contains(row['gene_name']))]

    num_genes = len(set(answers['neighbor_symbol']))
    num_pathways = len(set(answers['pathway_label']))
    pathways = set(answers['pathway_label'])
    genes = set(answers['neighbor_symbol'])

    df.loc[idx, '#_additional_pathways_interactions'] = num_pathways
    df.at[idx, 'additional_pathway_interactions'] = list(pathways)
    df.loc[idx, '#_additional_genes_in_pathways'] = num_genes
    df.at[idx, 'additional_genes_in_pathways'] = list(genes)
# Out:
# 0it [00:00, ?it/s]Input sequence provided is already in string format. No operation performed
# 1it [00:06,  6.14s/it]Input sequence provided is already in string format. No operation performed
# 2it [00:10,  5.34s/it]Input sequence provided is already in string format. No operation performed
# 3it [00:21,  7.78s/it]Input sequence provided is already in string format. No operation performed
# 4it [01:32, 32.71s/it]Input sequence provided is already in string format. No operation performed
# 5it [02:41, 45.75s/it]Input sequence provided is already in string format. No operation performed
# 6it [03:50, 53.79s/it]Input sequence provided is already in string format. No operation performed
# 7it [04:04, 40.84s/it]Input sequence provided is already in string format. No operation performed
# 8it [04:19, 32.52s/it]Input sequence provided is already in string format. No operation performed
# 9it [04:34, 26.86s/it]Input sequence provided is already in string format. No operation performed
# 10it [04:35, 19.08s/it]Input sequence provided is already in string format. No operation performed
# 11it [04:39, 14.49s/it]Input sequence provided is already in string format. No operation performed
# 12it [04:43, 11.27s/it]Input sequence provided is already in string format. No operation performed
# 13it [04:47,  8.94s/it]Input sequence provided is already in string format. No operation performed
# 14it [04:51,  7.38s/it]Input sequence provided is already in string format. No operation performed
# 15it [04:54,  6.27s/it]Input sequence provided is already in string format. No operation performed
# 16it [04:55,  4.61s/it]Input sequence provided is already in string format. No operation performed
# 17it [04:56,  3.45s/it]Input sequence provided is already in string format. No operation performed
# 18it [05:24, 10.93s/it]Input sequence provided is already in string format. No operation performed
# 19it [05:52, 16.02s/it]Input sequence provided is already in string format. No operation performed
# 20it [06:16, 18.35s/it]Input sequence provided is already in string format. No operation performed
# 21it [06:52, 23.63s/it]Input sequence provided is already in string format. No operation performed
# 22it [07:00, 19.03s/it]Input sequence provided is already in string format. No operation performed
# 23it [07:31, 22.62s/it]Input sequence provided is already in string format. No operation performed
# 24it [08:02, 25.19s/it]Input sequence provided is already in string format. No operation performed
# 25it [08:33, 26.85s/it]Input sequence provided is already in string format. No operation performed
# 26it [09:04, 28.07s/it]Input sequence provided is already in string format. No operation performed
# 27it [09:35, 29.13s/it]Input sequence provided is already in string format. No operation performed
# 28it [10:07, 29.72s/it]Input sequence provided is already in string format. No operation performed
# 29it [10:38, 30.23s/it]Input sequence provided is already in string format. No operation performed
# 30it [10:42, 22.26s/it]Input sequence provided is already in string format. No operation performed
# 31it [10:45, 16.70s/it]Input sequence provided is already in string format. No operation performed
# 32it [10:49, 12.76s/it]Input sequence provided is already in string format. No operation performed
# 33it [11:10, 15.20s/it]Input sequence provided is already in string format. No operation performed
# 34it [11:18, 13.05s/it]Input sequence provided is already in string format. No operation performed
# 35it [11:26, 11.58s/it]Input sequence provided is already in string format. No operation performed
# 36it [11:34, 10.53s/it]Input sequence provided is already in string format. No operation performed
# 37it [11:42,  9.77s/it]Input sequence provided is already in string format. No operation performed
# 38it [11:46,  8.14s/it]Input sequence provided is already in string format. No operation performed
# 39it [11:54,  7.85s/it]Input sequence provided is already in string format. No operation performed
# 40it [12:00,  7.29s/it]Input sequence provided is already in string format. No operation performed
# 41it [12:05,  6.85s/it]Input sequence provided is already in string format. No operation performed
# 42it [12:18,  8.48s/it]Input sequence provided is already in string format. No operation performed
# 43it [12:30,  9.69s/it]Input sequence provided is already in string format. No operation performed
# 44it [12:44, 10.87s/it]Input sequence provided is already in string format. No operation performed
# 45it [12:48,  8.96s/it]Input sequence provided is already in string format. No operation performed
# 46it [12:49,  6.50s/it]Input sequence provided is already in string format. No operation performed
# 47it [13:24, 15.16s/it]Input sequence provided is already in string format. No operation performed
# 48it [13:27, 11.51s/it]Input sequence provided is already in string format. No operation performed
# 49it [13:36, 10.62s/it]Input sequence provided is already in string format. No operation performed
# 50it [13:38,  7.94s/it]Input sequence provided is already in string format. No operation performed
# 51it [13:39,  5.85s/it]Input sequence provided is already in string format. No operation performed
# 52it [13:39,  4.33s/it]Input sequence provided is already in string format. No operation performed
# 53it [14:11, 12.36s/it]Input sequence provided is already in string format. No operation performed
# 54it [14:16, 10.39s/it]Input sequence provided is already in string format. No operation performed
# 55it [14:22,  9.01s/it]Input sequence provided is already in string format. No operation performed
# 56it [14:24,  6.99s/it]Input sequence provided is already in string format. No operation performed
# 57it [14:27,  5.56s/it]Input sequence provided is already in string format. No operation performed
# 58it [14:31,  5.20s/it]Input sequence provided is already in string format. No operation performed
# 59it [14:39,  6.02s/it]Input sequence provided is already in string format. No operation performed
# 60it [14:41,  4.91s/it]Input sequence provided is already in string format. No operation performed
# 61it [15:17, 14.18s/it]Input sequence provided is already in string format. No operation performed
# 62it [15:53, 20.75s/it]Input sequence provided is already in string format. No operation performed
# 63it [16:29, 25.32s/it]Input sequence provided is already in string format. No operation performed
# 64it [17:05, 28.55s/it]Input sequence provided is already in string format. No operation performed
# 65it [17:41, 30.61s/it]Input sequence provided is already in string format. No operation performed
# 66it [17:41, 21.67s/it]Input sequence provided is already in string format. No operation performed
# 67it [17:42, 15.40s/it]Input sequence provided is already in string format. No operation performed
# 68it [17:44, 11.25s/it]Input sequence provided is already in string format. No operation performed
# 69it [18:08, 15.03s/it]Input sequence provided is already in string format. No operation performed
# 70it [18:20, 14.27s/it]Input sequence provided is already in string format. No operation performed
# 71it [18:32, 13.51s/it]Input sequence provided is already in string format. No operation performed
# 72it [18:32,  9.57s/it]Input sequence provided is already in string format. No operation performed
# 73it [18:33,  6.81s/it]Input sequence provided is already in string format. No operation performed
# 74it [18:38,  6.31s/it]Input sequence provided is already in string format. No operation performed
# 75it [18:43,  6.01s/it]Input sequence provided is already in string format. No operation performed
# 76it [18:52,  6.85s/it]Input sequence provided is already in string format. No operation performed
# 77it [18:55,  5.69s/it]Input sequence provided is already in string format. No operation performed
# 78it [19:06,  7.29s/it]Input sequence provided is already in string format. No operation performed
# 79it [19:08,  5.79s/it]Input sequence provided is already in string format. No operation performed
# 80it [19:29, 10.41s/it]Input sequence provided is already in string format. No operation performed
# 81it [20:23, 23.26s/it]Input sequence provided is already in string format. No operation performed
# 82it [20:26, 17.17s/it]Input sequence provided is already in string format. No operation performed
# 83it [20:32, 14.04s/it]Input sequence provided is already in string format. No operation performed
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1181]:  Could not parse the entry correctly.
# 84it [20:33, 10.17s/it]Input sequence provided is already in string format. No operation performed
# 85it [20:39,  8.66s/it]Input sequence provided is already in string format. No operation performed
# 86it [21:33, 22.28s/it]Input sequence provided is already in string format. No operation performed
# 87it [21:33, 15.73s/it]Input sequence provided is already in string format. No operation performed
# 88it [21:34, 11.16s/it]Input sequence provided is already in string format. No operation performed
# 89it [21:34,  7.93s/it]Input sequence provided is already in string format. No operation performed
# 90it [21:38,  6.65s/it]Input sequence provided is already in string format. No operation performed
# 91it [21:56, 10.30s/it]Input sequence provided is already in string format. No operation performed
# 92it [22:16, 12.96s/it]Input sequence provided is already in string format. No operation performed
# 93it [22:17,  9.51s/it]Input sequence provided is already in string format. No operation performed
# 94it [22:54, 17.75s/it]Input sequence provided is already in string format. No operation performed
# 95it [23:14, 18.31s/it]Input sequence provided is already in string format. No operation performed
# 96it [23:14, 13.06s/it]Input sequence provided is already in string format. No operation performed
# 97it [24:13, 26.73s/it]Input sequence provided is already in string format. No operation performed
# 98it [24:15, 19.17s/it]Input sequence provided is already in string format. No operation performed
# 99it [24:31, 18.18s/it]Input sequence provided is already in string format. No operation performed
# 100it [24:31, 12.96s/it]Input sequence provided is already in string format. No operation performed
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1181]:  Could not parse the entry correctly.
# 101it [24:32,  9.31s/it]Input sequence provided is already in string format. No operation performed
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1181]:  Could not parse the entry correctly.
# 102it [24:33,  6.75s/it]Input sequence provided is already in string format. No operation performed
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1181]:  Could not parse the entry correctly.
# 103it [24:34,  4.96s/it]Input sequence provided is already in string format. No operation performed
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1181]:  Could not parse the entry correctly.
# 104it [24:34,  3.70s/it]Input sequence provided is already in string format. No operation performed
# 105it [24:35,  2.84s/it]Input sequence provided is already in string format. No operation performed
# 106it [24:36,  2.22s/it]Input sequence provided is already in string format. No operation performed
# 107it [24:47,  4.81s/it]Input sequence provided is already in string format. No operation performed
# 108it [24:58,  6.59s/it]Input sequence provided is already in string format. No operation performed
# 109it [25:08,  7.88s/it]Input sequence provided is already in string format. No operation performed
# 110it [26:26, 28.83s/it]Input sequence provided is already in string format. No operation performed
# 111it [26:36, 23.10s/it]Input sequence provided is already in string format. No operation performed
# 112it [26:37, 16.41s/it]Input sequence provided is already in string format. No operation performed
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1181]:  Could not parse the entry correctly.
# 113it [26:38, 11.72s/it]Input sequence provided is already in string format. No operation performed
# 114it [26:43,  9.73s/it]Input sequence provided is already in string format. No operation performed
# 115it [26:44,  7.37s/it]Input sequence provided is already in string format. No operation performed
# 116it [26:48,  6.26s/it]Input sequence provided is already in string format. No operation performed
# 117it [27:45, 21.37s/it]Input sequence provided is already in string format. No operation performed
# 118it [28:40, 31.58s/it]Input sequence provided is already in string format. No operation performed
# 119it [28:53, 25.82s/it]Input sequence provided is already in string format. No operation performed
# 120it [29:05, 21.89s/it]Input sequence provided is already in string format. No operation performed
# 121it [29:07, 15.78s/it]Input sequence provided is already in string format. No operation performed
# 122it [29:10, 11.94s/it]Input sequence provided is already in string format. No operation performed
# 123it [29:41, 17.88s/it]Input sequence provided is already in string format. No operation performed
# 124it [30:06, 20.01s/it]Input sequence provided is already in string format. No operation performed
# 125it [30:31, 21.42s/it]Input sequence provided is already in string format. No operation performed
# 126it [30:32, 15.24s/it]Input sequence provided is already in string format. No operation performed
# 127it [30:34, 11.33s/it]Input sequence provided is already in string format. No operation performed
# 128it [30:36,  8.61s/it]Input sequence provided is already in string format. No operation performed
# 129it [30:39,  6.68s/it]Input sequence provided is already in string format. No operation performed
# 130it [30:39,  4.90s/it]Input sequence provided is already in string format. No operation performed
# 131it [31:18, 14.88s/it]Input sequence provided is already in string format. No operation performed
# 132it [31:18, 10.65s/it]Input sequence provided is already in string format. No operation performed
# 133it [31:26,  9.86s/it]Input sequence provided is already in string format. No operation performed
# 134it [31:28,  7.36s/it]Input sequence provided is already in string format. No operation performed
# 135it [31:29,  5.62s/it]Input sequence provided is already in string format. No operation performed
# 136it [31:32,  4.67s/it]Input sequence provided is already in string format. No operation performed
# 137it [31:33, 13.82s/it]
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# Fetching ChEMBL targets for 'venetoclax'...
# Fetching ChEMBL targets for 'glutathione'...
# Fetching ChEMBL targets for 'kynurenine'...
# Fetching ChEMBL targets for 'onc201'...
# Fetching ChEMBL targets for 'trehalose'...
# Fetching ChEMBL targets for 'metformin'...
# Fetching ChEMBL targets for 'ampelopsin'...
# ⚠️ No protein targets for AMPELOPSIN.
# Fetching ChEMBL targets for 'salubrinal'...
# Fetching ChEMBL targets for 'cisplatin'...
# ⚠️ No protein targets for cisplatin.
# Fetching ChEMBL targets for 'therapeutic androgen'...
# ⚠️ No activity data for Therapeutic Androgen.
# Fetching ChEMBL targets for 'enzalutamide'...
# Fetching ChEMBL targets for 'ganetespib'...
# Fetching ChEMBL targets for 'andrographolide'...
# Fetching ChEMBL targets for 'phenformin'...
# Fetching ChEMBL targets for 'imatinib'...
# Fetching ChEMBL targets for 'tamoxifen'...
# Fetching ChEMBL targets for 'docetaxel anhydrous'...
# Fetching ChEMBL targets for 'quizartinib'...
# Fetching ChEMBL targets for 'gilteritinib'...
# Fetching ChEMBL targets for 'verticillin a'...
# Fetching ChEMBL targets for 'estrogen'...
# Fetching ChEMBL targets for 'gefitinib'...
# Fetching ChEMBL targets for 'erlotinib'...
# Fetching ChEMBL targets for 'vorinostat'...
# Fetching ChEMBL targets for 'rosiglitazone'...
# Fetching ChEMBL targets for 'ibrutinib'...
# Fetching ChEMBL targets for 'pirtobrutinib'...
# Fetching ChEMBL targets for 'xevinapant'...
# Fetching ChEMBL targets for 'jq1'...
# Fetching ChEMBL targets for 'alanine'...
# Fetching ChEMBL targets for 'sialic acid'...
# Fetching ChEMBL targets for 'decitabine'...
# Fetching ChEMBL targets for 'lenalidomide'...
# Fetching ChEMBL targets for 'dexamethasone'...
# ⚠️ No protein targets for dexamethasone.
# Fetching ChEMBL targets for 'cyclic adenosine monophosphate'...
# Fetching ChEMBL targets for 'ketoconazole'...
# Fetching ChEMBL targets for 'cholesterol'...
# ⚠️ No protein targets for cholesterol.
# Fetching ChEMBL targets for 'trail'...
# ⚠️ No activity data for TRAIL.
# Fetching ChEMBL targets for 'cytarabine'...
# ⚠️ No activity data for cytarabine.
# Fetching ChEMBL targets for 'tyrosine'...
# Fetching ChEMBL targets for 'vemurafenib'...
# Fetching ChEMBL targets for 'cadmium'...
# Fetching ChEMBL targets for 'streptozocin'...
# Fetching ChEMBL targets for 'doxorubicin hydrochloride'...
# ⚠️ No protein targets for doxorubicin hydrochloride.
# Fetching ChEMBL targets for 'tunicamycin'...
# ⚠️ No protein targets for Tunicamycin.
# Fetching ChEMBL targets for 'thapsigargin'...
# Fetching ChEMBL targets for 'oxygen'...
# Fetching ChEMBL targets for 'piperlongumine'...
# Fetching ChEMBL targets for 'azd5582'...
# Fetching ChEMBL targets for 'prednisolone'...
# Fetching ChEMBL targets for 'sp600125'...
# Fetching ChEMBL targets for 'paclitaxel'...
# Fetching ChEMBL targets for 'lactate'...
# Fetching ChEMBL targets for 'safimaltib'...
# Fetching ChEMBL targets for 'saponin'...
# ⚠️ No protein targets for Saponin.
# Fetching ChEMBL targets for 'nicotine polacrilex'...
# ⚠️ No activity data for nicotine polacrilex.
# Fetching ChEMBL targets for 'adriamycin'...
# Fetching ChEMBL targets for 'selumetinib'...
# ⚠️ No activity data for selumetinib.
# Fetching ChEMBL targets for 'lasalocid'...
# Fetching ChEMBL targets for 'pevonedistat'...
# ⚠️ No protein targets for Pevonedistat.
# Fetching ChEMBL targets for 'tumour necrosis factor membrane form'...
# ⚠️ No protein targets for tumour necrosis factor membrane form.
# Fetching ChEMBL targets for 'sirolimus'...
# ⚠️ No protein targets for sirolimus.
# Fetching ChEMBL targets for 'acetaminophen'...
# Fetching ChEMBL targets for 'sb203580'...
# ❌ Failed for SB203580: database disk image is malformed
# Fetching ChEMBL targets for 'platinum'...
# ⚠️ No protein targets for platinum.
# Fetching ChEMBL targets for 'pyruvate'...
# Fetching ChEMBL targets for 'sorafenib'...
# Fetching ChEMBL targets for 'melatonin'...
# Fetching ChEMBL targets for '4-phenylbutyric acid'...
# Fetching ChEMBL targets for 'progesterone'...
# Fetching ChEMBL targets for 'retinoic acid agent'...
# Fetching ChEMBL targets for 'recombinant tumor necrosis factor family protein'...
# ⚠️ No protein targets for Recombinant Tumor Necrosis Factor Family Protein.
# Fetching ChEMBL targets for 'adavosertib'...
# Fetching ChEMBL targets for 'corynoxine b'...
# Fetching ChEMBL targets for 'dasatinib anhydrous'...
# Fetching ChEMBL targets for 'temozolomide'...
# Fetching ChEMBL targets for 'melibiose'...
# Fetching ChEMBL targets for 'lactulose'...
# Fetching ChEMBL targets for 'apigenin'...
# Fetching ChEMBL targets for 'melphalan'...
# ⚠️ No protein targets for melphalan.
# Fetching ChEMBL targets for 'panobinostat'...
# Fetching ChEMBL targets for 'galangin'...
# Fetching ChEMBL targets for 'cysteine'...
# ⚠️ No activity data for cysteine.

# %%
# Save
df.to_excel('results.xlsx')

# %% [markdown]
# ### Inspect

# %%
inspect = df[['gene_label','drug_label','#_additional_genes_in_pathways','additional_genes_in_pathways','#_additional_pathways_interactions']].sort_values(by='#_additional_pathways_interactions',ascending=False).reset_index(drop=True)
inspect[0:10]
# Out:
#   gene_label    drug_label #_additional_genes_in_pathways  \
# 0        BAX      imatinib                            421
# 1    BCL2L11     gefitinib                            385
# 2     PANDAR    paclitaxel                            166
# 3       EGFR     gefitinib                            384
# 4       TP53      apigenin                            158
# 5      KPNA4    paclitaxel                            166
# 6        BTK     ibrutinib                            267
# 7        BTK     ibrutinib                            267
# 8       EGFR   vemurafenib                            270
# 9     BCL2A1  gilteritinib                            225
#
#                         additional_genes_in_pathways  \
# 0  [MYH10, MAP3K13, DHCR24, PI4KB, DAPK2, ABCC4, ...
# 1  [MAP3K13, DHCR24, PI4KB, DAPK2, ABCC4, PIK3C2B...
# 2  [BDKRB2, EDNRB, OPRM1, ABCC4, PTPRC, MAOA, HTR...
# 3  [MAP3K13, DHCR24, PI4KB, DAPK2, ABCC4, PIK3C2B...
# 4  [OPRM1, MAOA, ALOX15, CXCL8, ALOX5, DAPK3, PDK...
# 5  [BDKRB2, EDNRB, OPRM1, ABCC4, PTPRC, MAOA, HTR...
# 6  [MYH10, DHCR24, GNAI2, PRKG1, OPRM1, MCM4, MAO...
# 7  [MYH10, DHCR24, GNAI2, PRKG1, OPRM1, MCM4, MAO...
# 8  [MYH10, BDKRB2, DHCR24, GNAI2, PRKG1, OPRM1, M...
# 9  [DHCR24, GNAI2, PRKG1, OPRM1, MCM4, MAOA, HTR1...
#
#   #_additional_pathways_interactions
# 0                                204
# 1                                201
# 2                                200
# 3                                200
# 4                                200
# 5                                200
# 6                                198
# 7                                198
# 8                                195
# 9                                195

# %%
value = 3
print(f'AI Curated Interaction: {inspect['drug_label'][value]} / {inspect['gene_label'][value]}')
print(f'# of genes that neighbor {inspect['gene_label'][value]} in known signaling pathways: {inspect['#_additional_genes_in_pathways'][value]}')
print(f'# of neighbor genes that have known interactions with {inspect['drug_label'][value]}: {inspect['#_additional_pathways_interactions'][value]}')
# Out:
# AI Curated Interaction: gefitinib / EGFR
# # of genes that neighbor EGFR in known signaling pathways: 384
# # of neighbor genes that have known interactions with gefitinib: 200

# %% [markdown]
# TODO: Why do some rows have more neighbor interactions than genes in pathways?
# TODO: Graphs
